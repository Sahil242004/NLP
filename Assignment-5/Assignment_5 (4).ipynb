# %% [markdown]
# Assignemt-5 : Use WordNet to identify semantic relationships such as synonymy, antonymy, and hypernymy
# in text data.

# %% [markdown]
# # **Identifying Semantic Relationships using WordNet**

# %% [markdown]
# **Step 1: Install & Import Libraries**

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# **Step 2: Sample Text**

# %%
words = ["happy", "big", "car", "dog"]

# %% [markdown]
# **Step 3: Synonym Extraction using WordNet**

# %%
def get_synonyms(word):
    synonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return synonyms

for word in words:
    print(f"\nSynonyms of '{word}':")
    print(get_synonyms(word))
# Out:
# Synonyms of 'happy':
# {'happy', 'well-chosen', 'felicitous', 'glad'}
#
# Synonyms of 'big':
# {'bountiful', 'handsome', 'crowing', 'freehanded', 'prominent', 'gravid', 'bragging', 'openhanded', 'bighearted', 'large', 'giving', 'enceinte', 'expectant', 'self-aggrandising', 'big', 'vainglorious', 'braggy', 'adult', 'bounteous', 'vauntingly', 'magnanimous', 'swelled', 'full-grown', 'bad', 'heavy', 'boastful', 'liberal', 'grown', 'fully_grown', 'great', 'grownup', 'boastfully', 'cock-a-hoop', 'with_child', 'self-aggrandizing', 'braggart'}
#
# Synonyms of 'car':
# {'motorcar', 'railcar', 'railroad_car', 'auto', 'machine', 'railway_car', 'cable_car', 'automobile', 'gondola', 'elevator_car', 'car'}
#
# Synonyms of 'dog':
# ...

# %% [markdown]
# **Step 4: Antonym Extraction using WordNet**

# %%
def get_antonyms(word):
    antonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
    return antonyms

for word in words:
    print(f"\nAntonyms of '{word}':")
    print(get_antonyms(word))
# Out:
# Antonyms of 'happy':
# {'unhappy'}
#
# Antonyms of 'big':
# {'little', 'small'}
#
# Antonyms of 'car':
# set()
#
# Antonyms of 'dog':
# set()

# %% [markdown]
# **Step 5: Hypernym Extraction using WordNet**

# %%
def get_hypernyms(word):
    hypernyms = set()
    for syn in wn.synsets(word):
        for hyper in syn.hypernyms():
            hypernyms.add(hyper.name().split('.')[0])
    return hypernyms

for word in words:
    print(f"\nHypernyms of '{word}':")
    print(get_hypernyms(word))
# Out:
# Hypernyms of 'happy':
# set()
#
# Hypernyms of 'big':
# set()
#
# Hypernyms of 'car':
# {'motor_vehicle', 'wheeled_vehicle', 'compartment'}
#
# Hypernyms of 'dog':
# {'pursue', 'sausage', 'villain', 'support', 'chap', 'unpleasant_woman', 'domestic_animal', 'canine', 'catch'}

# %% [markdown]
# **Step 6: Apply to Text Data**

# %%
text = "The happy dog sat inside the big car"

tokens = text.lower().split()

for token in tokens:
    print(f"\nWord: {token}")
    print("Synonyms :", get_synonyms(token))
    print("Antonyms :", get_antonyms(token))
    print("Hypernyms:", get_hypernyms(token))
# Out:
# Word: the
# Synonyms : set()
# Antonyms : set()
# Hypernyms: set()
#
# Word: happy
# Synonyms : {'happy', 'well-chosen', 'felicitous', 'glad'}
# Antonyms : {'unhappy'}
# Hypernyms: set()
#
# Word: dog
# Synonyms : {'wiener', 'pawl', 'cad', 'go_after', 'firedog', 'click', 'hot_dog', 'frump', 'frank', 'wienerwurst', 'hound', 'Canis_familiaris', 'frankfurter', 'tail', 'tag', 'dog', 'trail', 'hotdog', 'heel', 'weenie', 'domestic_dog', 'chase', 'chase_after', 'track', 'give_chase', 'andiron', 'dog-iron', 'detent', 'blackguard', 'bounder'}
# Antonyms : set()
# Hypernyms: {'pursue', 'sausage', 'villain', 'support', 'chap', 'unpleasant_woman', 'domestic_animal', 'canine', 'catch'}
#
# Word: sat
# Synonyms : {'model', 'sit', 'ride', 'Saturday', 'pose', 'Sabbatum', 'sit_down', 'sit_around', 'seat', 'baby-sit', 'Sat', 'posture'}
# Antonyms : {'stand', 'arise'}
# Hypernyms: {'put', 'convene', 'guard', 'serve', 'be', 'weekday', 'change_posture', 'travel', 'expose'}
#
# Word: inside
# ...
